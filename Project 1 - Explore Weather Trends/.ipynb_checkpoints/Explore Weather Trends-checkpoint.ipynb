# %% [markdown]
# # <center>EXPLORE WEATHER TRENDS</center>

# %% [markdown]
# <b>Rafael Iannazzo</b>
#
# Data Analyst Nanodegree - Term 1
#
# Udacity
#
# Dec/2017

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Methodology

# %% [markdown]
# ## SQL Scripts

# %% [markdown]
# I decided to download a full list of cities to make a dynamic code, where you specify a list of cities to be compared and the code will filter the rows itself. However, for academic purposes, if I were to download only the data I intend to use in this exercise, I would have ran the queries below:

# %% [markdown]
# <b>Extract Cities data:</b>
#
# <i>SELECT * FROM city_data WHERE city || '-' || country IN ('Belo Horizonte-Brazil', 'Rome-Italy','London-United Kingdom')</i>
#
# The country is necessary to avoid duplicates - I am only interested in London-United Kingdom, not London-Canada.

# %% [markdown]
# ## Load data from CSV files

# %% [markdown]
# The code below opens the city_data.csv CSV file.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

cdpath = 'C://Users//rafae//Desktop//Udacity//Project 1 - Explore Weather Trends//city_data.csv'
df = pd.read_csv(cdpath, header = 0)

gdpath = 'C://Users//rafae//Desktop//Udacity//Project 1 - Explore Weather Trends//global_data.csv'
gdf = pd.read_csv(gdpath, header = 0)

# %% [markdown]
# The cities to compare are added in the array below.

# %%
cities = ['Belo Horizonte-Brazil', 'Rome-Italy', 'London-United Kingdom']

# %% [markdown]
# ## Moving Average

# %% [markdown]
# As the dataset presents the temperature variation by year, and we are only interested to see the weather trends, a moving average per <b>decade</b> is added to the dataset so we can smooth the visualization.

# %%
df['moving_average'] = df.groupby(['city','country'], as_index=False)['avg_temp'].rolling(10).mean().reset_index(0,drop=True).dropna()
gdf['moving_average'] = gdf['avg_temp'].rolling(10).mean().reset_index(0,drop=True).dropna()
gdf.tail()
# Out:
#      year  avg_temp  moving_average
# 261  2011      9.52           9.554
# 262  2012      9.51           9.548
# 263  2013      9.61           9.556
# 264  2014      9.57           9.581
# 265  2015      9.83           9.594

# %%
fig, ax = plt.subplots()
for city in cities:
    ax.plot(df[df['city']+'-'+df['country'] == city]['year'],df[df['city']+'-'+df['country'] == city]['moving_average'],label=city)

ax.plot(gdf['year'],gdf['moving_average'],'r:',label='Global Average')

# Position the legend box out of the graph area
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#resize the graph
fig.set_size_inches(18.5, 10.5, forward=True)

#set the axes labels
plt.xlabel('Year')
plt.ylabel('Temperature in Degrees')

plt.show()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# ### 1. Temperature spike after 1990's

# %% [markdown]
# It could be noted after 1990's the planet is getting hotter across all the countries compared, which is sligtlhy more evident in non-tropical countries.

# %% [markdown]
# ### 2. Drop after 2014
